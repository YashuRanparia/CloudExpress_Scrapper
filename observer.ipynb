# %%
import pandas as pd

# %%
data = pd.read_csv('scrapped_data\data.csv')
data.head(1)
# Out:
#                                              url tagName    value  \
# 0  https://tympanus.net/Development/3DPortalCard    BODY  33264.0
#
#    no_of_chars fontSize               color height width  \
# 0          231     12px  rgb(140, 146, 164)   auto  auto
#
#                                           fontFamily  fontWeight  ...  \
# 0  ui-monospace, SFMono-Regular, Menlo, "Roboto M...         400  ...
#
#   textAlign                 textDecoration textTransform margin padding  \
# 0     start  none solid rgb(140, 146, 164)          none   none    none
#
#   backgroundColor backgroundImage backgroundPosition backgroundRepeat  \
# 0    rgb(0, 0, 0)            none              0% 0%           repeat
#
#   backgroundSize
# 0           auto
#
# [1 rows x 24 columns]

# %%
data['url'].unique()
# Out:
# array(['https://tympanus.net/Development/3DPortalCard',
#        'https://tympanus.net/Development/OnScrollShapeMorph',
#        'https://tympanus.net/Development/PixelGooeyTooltip',
#        'http://tympanus.net/Development/LayersAnimation',
#        'http://tympanus.net/Development/MotionTrailAnimations/',
#        'http://tympanus.net/Development/SlideshowAnimations/',
#        'http://tympanus.net/Development/GridItemHoverEffect/',
#        'http://tympanus.net/Development/ConnectedGrid/',
#        'http://tympanus.net/Development/OnScrollColumnsRows/',
#        'http://tympanus.net/Development/Scroll3DGrid/',
#        'http://tympanus.net/Development/GridFlowEffect/',
#        'http://tympanus.net/Development/ScrollBasedLayoutAnimations/',
#        'http://tympanus.net/Development/TextBlockTransitions/',
#        'http://tympanus.net/Development/OnScrollFilter/',
#        'http://tympanus.net/Development/ImageTilesMenu/',
# ...

# %%
data.sort_values('value',ascending=False).head(6)
# Out:
#                                                 url tag_name    value  \
# 0   https://tympanus.net/Development/PushGridItems/     BODY  49104.0
# 1   https://tympanus.net/Development/PushGridItems/     MAIN  45504.0
# 2   https://tympanus.net/Development/PushGridItems/   HEADER  33984.0
# 50  https://tympanus.net/Development/PushGridItems/   HEADER  33984.0
# 15  https://tympanus.net/Development/PushGridItems/        A  12672.0
# 62  https://tympanus.net/Development/PushGridItems/      DIV  12672.0
#
#     no_of_chars  size                     color height width  \
# 0           341  12px  rgba(255, 255, 255, 0.6)   auto  auto
# 1           316  12px  rgba(255, 255, 255, 0.6)   auto  auto
# 2           236  12px  rgba(255, 255, 255, 0.6)   auto  auto
# 50          236  12px  rgba(255, 255, 255, 0.6)   auto  auto
# 15           88  12px        rgb(255, 255, 255)   auto  auto
# 62           88  12px  rgba(255, 255, 255, 0.6)   auto  auto
#
# ...

# %%
df = data.sort_values('value',ascending=False).head(6)

# %%
df
# Out:
#                                                 url tag_name    value  \
# 0   https://tympanus.net/Development/PushGridItems/     BODY  49104.0
# 1   https://tympanus.net/Development/PushGridItems/     MAIN  45504.0
# 2   https://tympanus.net/Development/PushGridItems/   HEADER  33984.0
# 50  https://tympanus.net/Development/PushGridItems/   HEADER  33984.0
# 15  https://tympanus.net/Development/PushGridItems/        A  12672.0
# 62  https://tympanus.net/Development/PushGridItems/      DIV  12672.0
#
#     no_of_chars  size                     color height width  \
# 0           341  12px  rgba(255, 255, 255, 0.6)   auto  auto
# 1           316  12px  rgba(255, 255, 255, 0.6)   auto  auto
# 2           236  12px  rgba(255, 255, 255, 0.6)   auto  auto
# 50          236  12px  rgba(255, 255, 255, 0.6)   auto  auto
# 15           88  12px        rgb(255, 255, 255)   auto  auto
# 62           88  12px  rgba(255, 255, 255, 0.6)   auto  auto
#
# ...

# %%
df.to_csv('scrapped_data/top6.csv',index=False)

# %%
def getTop6(file):
    df = pd.read_csv(file)

    unique_urls = df['url'].unique()

    finaldf = pd.DataFrame(columns=df.columns)

    for url in unique_urls:
        toadd = df[df['url'] == url].sort_values('value',ascending = False)
        toadd = toadd.head(6)
        finaldf = pd.concat([finaldf, toadd], ignore_index=True)
        pass

    finaldf.to_csv('scrapped_data/top6.csv',index=False)
    # finaldf.to_csv('scrapped_data/final.csv', index=False, mode='a')
    pass

# %%
getTop6('updated_data.csv')

# %%
df = pd.read_csv('scrapped_data/top6.csv')
df.head(3)
# Out:
#                                         url tagName     value  no_of_chars  \
# 0  https://tympanus.net/Development/Origami     DIV  114688.0            7
# 1  https://tympanus.net/Development/Origami     DIV  114688.0            7
# 2  https://tympanus.net/Development/Origami     DIV  114688.0            7
#
#   fontSize             color height width              fontFamily  fontWeight  \
# 0    128px  rgba(0, 0, 0, 0)   auto  auto  "Zen Dots", sans-serif         400
# 1    128px  rgba(0, 0, 0, 0)   auto  auto  "Zen Dots", sans-serif         400
# 2    128px  rgba(0, 0, 0, 0)   auto  auto  "Zen Dots", sans-serif         400
#
#    ...               textDecoration textTransform margin padding  \
# 0  ...  none solid rgba(0, 0, 0, 0)          none   none    none
# 1  ...  none solid rgba(0, 0, 0, 0)          none   none    none
# 2  ...  none solid rgba(0, 0, 0, 0)          none   none    none
#
#     backgroundColor                                    backgroundImage  \
# ...

# %%
df.columns
# Out:
# Index(['url', 'tagName', 'value', 'no_of_chars', 'fontSize', 'color', 'height',
#        'width', 'fontFamily', 'fontWeight', 'fontVariant', 'lineHeight',
#        'letterSpacing', 'wordSpacing', 'textAlign', 'textDecoration',
#        'textTransform', 'margin', 'padding', 'backgroundColor',
#        'backgroundImage', 'backgroundPosition', 'backgroundRepeat',
#        'backgroundSize', 'projectedTag'],
#       dtype='object')

# %%
fontProperties = df[['fontSize', 'color', 'fontFamily', 'fontWeight', 'fontVariant', 'lineHeight','letterSpacing', 'wordSpacing', 'textAlign', 'textDecoration','textTransform','projectedTag']]
fontProperties.head(3)
# Out:
#   fontSize             color              fontFamily  fontWeight fontVariant  \
# 0    128px  rgba(0, 0, 0, 0)  "Zen Dots", sans-serif         400      normal
# 1    128px  rgba(0, 0, 0, 0)  "Zen Dots", sans-serif         400      normal
# 2    128px  rgba(0, 0, 0, 0)  "Zen Dots", sans-serif         400      normal
#
#   lineHeight letterSpacing wordSpacing textAlign               textDecoration  \
# 0      128px        normal         0px     start  none solid rgba(0, 0, 0, 0)
# 1      128px        normal         0px     start  none solid rgba(0, 0, 0, 0)
# 2      128px        normal         0px     start  none solid rgba(0, 0, 0, 0)
#
#   textTransform projectedTag
# 0          none           H1
# 1          none           H1
# 2          none           H1

# %%
bgProps = df[['backgroundColor',
       'backgroundImage', 'backgroundPosition', 'backgroundRepeat',
       'backgroundSize']]

bgProps.head(3)
# Out:
#     backgroundColor                                    backgroundImage  \
# 0  rgba(0, 0, 0, 0)  linear-gradient(to left, rgb(130, 130, 130), r...
# 1  rgba(0, 0, 0, 0)  linear-gradient(to left, rgb(130, 130, 130), r...
# 2  rgba(0, 0, 0, 0)  linear-gradient(to left, rgb(130, 130, 130), r...
#
#   backgroundPosition backgroundRepeat backgroundSize
# 0              0% 0%           repeat           auto
# 1              0% 0%           repeat           auto
# 2              0% 0%           repeat           auto

# %%
fontProperties.shape
# Out:
# (108, 12)

# %%
fontProperties.drop_duplicates(inplace=True)
# Out:
# C:\Users\yashu\AppData\Local\Temp\ipykernel_12624\176245047.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fontProperties.drop_duplicates(inplace=True)

# %%
fontProperties.shape
# Out:
# (27, 12)

# %%
fontProperties.to_csv('scrapped_data/fontProps.csv',index=False)

# %%
bgProps.shape
# Out:
# (108, 5)

# %%
bgProps.drop_duplicates(inplace=True)
# Out:
# C:\Users\yashu\AppData\Local\Temp\ipykernel_12624\381760318.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bgProps.drop_duplicates(inplace=True)

# %%
bgProps.shape
# Out:
# (13, 5)

# %%
bgProps.to_csv('scrapped_data/bgProps.csv',index=False)
